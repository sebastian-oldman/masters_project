# %% [markdown]
# # 00 Data inventory
# Loads `data/raw/manifest.csv`, checks every file opens, and summarises coverage (date ranges, row counts) per source group.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path().resolve().parent))
import pandas as pd
from src.paths import RAW, PROCESSED, FIGURES, MANIFEST
manifest = pd.read_csv(MANIFEST)
manifest.groupby('group').size()
